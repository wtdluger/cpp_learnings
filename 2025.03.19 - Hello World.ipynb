# %%
# %%writefile my_program.cpp
# #include <iostream>
#
# int main() {
#     std::cout << "Hello, C++ from Colab using cout" << std::endl;
#     printf("Hello, C++ from Colab using printf");
#     return 0;
# }
# Out:
# Overwriting my_program.cpp

# %%
# %%script bash
# g++ my_program.cpp -o my_program
# ./my_program
# Out:
# Hello, C++ from Colab using cout
# Hello, C++ from Colab using printf

# %%
# %%writefile my_program.c
# #include <stdio.h>
#
# int main() {
#     printf("Hello, C from Colab!");
#     return 0;
# }
# Out:
# Overwriting my_program.c

# %%
# %%script bash
# g++ my_program.c -o my_program
# ./my_program
# Out:
# Hello, C from Colab!
